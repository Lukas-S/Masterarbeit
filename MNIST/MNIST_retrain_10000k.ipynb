# %%
import sys
import os
import pickle
sys.path.append(os.path.abspath('..'))

# %%
from helper import *

# Device detection and setup
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f"Using device: {device}")
if torch.cuda.is_available():
    print(f"CUDA device: {torch.cuda.get_device_name(0)}")
    print(f"CUDA memory: {torch.cuda.get_device_properties(0).total_memory / 1024**3:.1f} GB")

set_seed = 42
# Out:
# Using device: cuda
# CUDA device: NVIDIA GeForce RTX 4060 Ti
# CUDA memory: 16.0 GB

# %%
# MNIST Network
class MNISTNet(nn.Module):
    def __init__(self):
        super(MNISTNet, self).__init__()
        self.fc1 = nn.Linear(28*28, 128)
        self.relu1 = nn.ReLU()
        self.fc2 = nn.Linear(128, 64)
        self.relu2 = nn.ReLU()
        self.fc3 = nn.Linear(64, 10)

    def forward(self, x):
        x = x.view(-1, 28*28)
        x = self.relu1(self.fc1(x))
        x = self.relu2(self.fc2(x))
        x = self.fc3(x)
        return x

# %%
base = 10
# MNIST Dataset (deterministic)
transform = transforms.Compose([transforms.ToTensor(), transforms.Normalize((0.5,), (0.5,))])

# Create datasets with fixed generator for reproducibility
g = torch.Generator()
g.manual_seed(42)

mnist_train = datasets.MNIST('../data', train=True, download=True, transform=transform)
mnist_test = datasets.MNIST('../data', train=False, download=True, transform=transform)

mnist_train_loader = DataLoader(mnist_train, batch_size=64, shuffle=False, generator=g)
mnist_test_loader = DataLoader(mnist_test, batch_size=64, shuffle=False)

# Example usage (deterministic training):
mnist_model = MNISTNet()
mnist_criterion = nn.CrossEntropyLoss()
mnist_optimizer = optim.Adam(mnist_model.parameters(), lr=0.001)
mnist_losses, trained_mnist = train_model(mnist_model, mnist_train_loader, mnist_criterion, mnist_optimizer, num_epochs=base, seed=42, verbose=True)
# Out:
# All seeds set to: 42
# Model weights initialized with seed: 42
# Training on device: cuda

# %%
mnist_inputs, mnist_activations, mnist_outputs = get_activations(trained_mnist, mnist_train_loader, dataset_type='mnist')

# %%
sample_index = 8
k_neighbors = 15

# Show Example of dataset
show_mnist_samples(mnist_test_loader, indices=8)  # Single index

# Make prediction
print()
predictions_mnist, probabilities_mnist, predicted_classes_mnist, sample_targets_mnist = predict_and_show(trained_mnist, mnist_test_loader, dataset_type='mnist', indices=sample_index)  # Single index

single_mnist_inputs, single_mnist_activations, single_mnist_outputs = get_activations(trained_mnist, mnist_test_loader, dataset_type='mnist', indices=sample_index)
# Out:
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 8      5      5      1.0000

# %%
indices_mnist, distances_mnist = find_knn(mnist_activations, single_mnist_activations, k=k_neighbors, metric='l2')
filtered_mnist_loader, filtered_size = create_filtered_dataloader(mnist_train_loader, exclude_indices=indices_mnist, batch_size=64, shuffle=False)

# %%
filter_mnist_model = MNISTNet()
mnist_criterion_f = nn.CrossEntropyLoss()
mnist_optimizer_f = optim.Adam(filter_mnist_model.parameters(), lr=0.001)
mnist_losses_f, filter_trained_mnist = train_model(filter_mnist_model, filtered_mnist_loader, mnist_criterion_f, mnist_optimizer_f, num_epochs=base, seed=42, verbose=True)
# Out:
# All seeds set to: 42
# Model weights initialized with seed: 42
# Training on device: cuda

# %%
# Base Model prediction
predictions_base_mnist, probabilities_mnist, predicted_classes_mnist, sample_targets_mnist = predict_and_show(trained_mnist, mnist_test_loader, dataset_type='mnist', indices=sample_index)

# Filtered Model prediction
predictions_filter_mnist, probabilities_mnist, predicted_classes_mnist, sample_targets_mnist = predict_and_show(filter_trained_mnist, mnist_test_loader, dataset_type='mnist', indices=sample_index)
# Out:
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 8      5      5      1.0000
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 8      5      5      0.9972

# %%
print(nn.CrossEntropyLoss()(predictions_base_mnist, sample_targets_mnist))
print(nn.CrossEntropyLoss()(predictions_filter_mnist, sample_targets_mnist))
# Out:
# tensor(2.2650e-06)
# tensor(0.0028)

# %%
# Version 2: recompute activations on the filtered training set before k-NN so distances reflect the filtered dataset
# This is a copy of retrain_entropy_for_k_and_indices with the necessary changes; it returns the same (cross_results, knn_distances)

def retrain_entropy_for_k_and_indices_v2(model, train_loader, test_loader, list_of_k, list_of_indices, metric='cosine'):
    """Like retrain_entropy_for_k_and_indices but recalculates activations for the filtered
    training set before computing k-NN. This ensures stored k-NN distances are computed
    relative to the filtered dataset (i.e. after removing the excluded indices).

    Returns: cross_results, knn_distances (same structure as original)
    """
    cross_results = {
        'closest_cross_entropy': {},
        'last_cross_entropy': {},
        'random_cross_entropy': {}
    }

    # Store k-NN distances per subset / k / sample — distances here correspond to the filtered train set
    knn_distances = {
        'closest_distances': {},
        'last_distances': {},
        'random_distances': {}
    }

    for k in list_of_k:
        print(f"\n\n______Processing k={k}______\n\n")
        cross_results['closest_cross_entropy'][k] = []
        cross_results['last_cross_entropy'][k] = []
        cross_results['random_cross_entropy'][k] = []

        knn_distances['closest_distances'][k] = []
        knn_distances['last_distances'][k] = []
        knn_distances['random_distances'][k] = []

        for index in list_of_indices:

            # Get activations for the single sample (from the provided model)
            single_inputs, single_activations, _ = get_activations(model, test_loader, dataset_type='mnist', indices=index)

            # For each subset we will create the filtered dataloader first, then compute activations
            # for that filtered training set (using the same model) and then run k-NN between
            # the filtered training activations and the single sample's activations. This ensures
            # we measure distances relative to the filtered dataset.

            # Prepare neighbor candidates for the full filtered dataset.
            # We'll still exclude subset_indices from the original train set and compute activations on the remaining samples.
            for subset_name_template, subset_selector in [
                ('closest_cross_entropy', 'closest'),
                ('last_cross_entropy', 'last'),
                ('random_cross_entropy', 'random')
            ]:
                # To determine subset_indices we need the ordering of neighbors in the original (unfiltered) train set
                # Use mnist_activations (assumed available in the notebook) to get the full ordering; fall back to computing it
                try:
                    base_indices_knn, base_distances = find_knn(mnist_activations, single_activations, k=len(mnist_activations), metric=metric)
                except Exception:
                    # if mnist_activations not available, compute activations for full train_loader
                    _, full_train_activations, _ = get_activations(model, train_loader, dataset_type='mnist')
                    base_indices_knn, base_distances = find_knn(full_train_activations, single_activations, k=len(full_train_activations), metric=metric)

                if subset_selector == 'closest':
                    subset_indices = base_indices_knn[:k]
                    subset_dists_initial = [float(d) for d in base_distances[:k]]
                elif subset_selector == 'last':
                    subset_indices = base_indices_knn[-k:]
                    subset_dists_initial = [float(d) for d in base_distances[-k:]]
                else:  # random
                    # random selection from the base ordering (still referencing full train ordering)
                    subset_indices = np.random.choice(base_indices_knn, k, replace=False)
                    # build map for lookup
                    dist_map = {int(idx): float(d) for idx, d in zip(base_indices_knn, base_distances)}
                    subset_dists_initial = [dist_map[int(i)] for i in subset_indices]

                # Create filtered dataloader removing subset_indices
                filtered_loader, filtered_size = create_filtered_dataloader(train_loader, exclude_indices=subset_indices, batch_size=64, shuffle=False)

                # Compute activations for the filtered training set using the same (base) model
                # This is the key change vs original: compute activations AFTER filtering
                if filtered_size == 0:
                    # nothing left in filtered set; record NaNs and continue
                    print(f"Filtered training set empty after excluding subset for index={index}, k={k}, subset={subset_name_template}")
                    cross_results[subset_name_template][k].append(float('nan'))
                    # store empty distance list
                    knn_distances[subset_name_template.replace('_cross_entropy', '_distances')][k].append([])
                    continue

                _, filtered_activations, _ = get_activations(model, filtered_loader, dataset_type='mnist')

                # If filtered_activations has fewer than k samples, adjust effective k
                eff_k = min(k, len(filtered_activations))

                # Run k-NN on the filtered activations against the single activation
                indices_knn_filtered, distances_filtered = find_knn(filtered_activations, single_activations, k=len(filtered_activations), metric=metric)

                # Derive the subset indices/dists relative to the filtered set ordering
                if subset_selector == 'closest':
                    sel_indices = indices_knn_filtered[:eff_k]
                    sel_dists = [float(d) for d in distances_filtered[:eff_k]]
                elif subset_selector == 'last':
                    sel_indices = indices_knn_filtered[-eff_k:]
                    sel_dists = [float(d) for d in distances_filtered[-eff_k:]]
                else:
                    # For random, sample from the filtered ordering (safe even if eff_k < k)
                    sel_indices = np.random.choice(indices_knn_filtered, eff_k, replace=False)
                    dist_map_filtered = {int(idx): float(d) for idx, d in zip(indices_knn_filtered, distances_filtered)}
                    sel_dists = [dist_map_filtered[int(i)] for i in sel_indices]

                # Now train on the filtered dataset (same as before)
                filtered_model = MNISTNet()
                optimizer_tmp = optim.Adam(filtered_model.parameters(), lr=0.01)
                criterion = nn.CrossEntropyLoss()
                train_model(filtered_model, filtered_loader, criterion, optimizer_tmp, num_epochs=base, seed=42, verbose=False, continue_training=False)

                # Predict and calculate CrossEntropy loss on the test sample
                predictions, _, _, targets = predict_and_show(filtered_model, test_loader, dataset_type='mnist', indices=index)
                cross_loss = nn.CrossEntropyLoss()(predictions, targets).item()
                cross_results[subset_name_template][k].append(cross_loss)

                # Store the distances we computed on the filtered dataset
                dist_key = subset_name_template.replace('_cross_entropy', '_distances')
                knn_distances[dist_key][k].append(list(map(float, sel_dists)))

    return cross_results, knn_distances

# %%
list_of_k = list(range(0, 10001, 2500))
list_of_k[0] = 1
#list_of_k = [1, 5, 10, 50, 100, 250]

list_of_indices = list(range(0, 10000, 1))
random_indices = random.sample(list_of_indices, k=10)

print(list_of_k)
print(random_indices)
# Out:
# [1, 2500, 5000, 7500, 10000]
# [1824, 409, 4506, 4012, 3657, 2286, 1679, 8935, 1424, 9674]

# %%
cross_results_l1, knn_distances_l1 = retrain_entropy_for_k_and_indices_v2(trained_mnist, mnist_train_loader, mnist_test_loader, list_of_k, random_indices,metric='l1')
# Out:
# ______Processing k=1______
#
#
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 1824   2      2      0.9946
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 1824   2      2      0.9998
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 1824   2      2      0.9902
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 409    1      1      0.9995
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 409    1      1      0.9999
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 409    1      1      0.9999
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 4506   2      2      0.9839
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 4506   2      2      0.9758
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 4506   2      2      0.8627
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 4012   4      4      1.0000
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 4012   4      4      1.0000
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 4012   4      4      1.0000
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 3657   6      6      0.9999
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 3657   6      6      1.0000
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 3657   6      6      0.9994
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 2286   6      6      0.6688
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 2286   6      6      0.4977
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 2286   6      6      0.4568
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 1679   4      4      1.0000
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 1679   4      4      1.0000
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 1679   4      4      1.0000
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 8935   9      9      0.9982
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 8935   9      9      0.9999
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 8935   9      9      0.9999
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 1424   1      1      1.0000
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 1424   1      1      0.9998
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 1424   1      1      1.0000
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 9674   1      1      1.0000
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 9674   1      1      1.0000
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 9674   1      1      1.0000
#
#
# ______Processing k=2500______
#
#
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 1824   2      3      0.9990
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 1824   2      2      0.9893
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 1824   2      2      0.9992
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 409    1      1      0.8556
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 409    1      1      1.0000
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 409    1      1      1.0000
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 4506   2      2      0.3685
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 4506   2      2      0.9888
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 4506   2      2      0.7744
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 4012   4      9      0.9400
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 4012   4      4      1.0000
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 4012   4      4      1.0000
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 3657   6      4      0.9896
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 3657   6      6      1.0000
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 3657   6      6      1.0000
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 2286   6      4      0.6041
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 2286   6      6      0.9507
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 2286   6      6      0.9050
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 1679   4      4      0.9810
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 1679   4      4      1.0000
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 1679   4      4      1.0000
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 8935   9      9      0.9673
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 8935   9      9      0.9993
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 8935   9      9      1.0000
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 1424   1      1      1.0000
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 1424   1      1      0.9999
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 1424   1      1      0.9999
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 9674   1      1      0.9560
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 9674   1      1      1.0000
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 9674   1      1      1.0000
#
#
# ______Processing k=5000______
#
#
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 1824   2      8      0.5065
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 1824   2      2      0.9999
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 1824   2      2      0.9978
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 409    1      8      0.7080
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 409    1      1      0.9996
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 409    1      1      1.0000
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 4506   2      8      0.2191
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 4506   2      2      0.9937
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 4506   2      2      0.9348
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 4012   4      9      0.9939
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 4012   4      4      0.9999
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 4012   4      4      1.0000
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 3657   6      4      0.9998
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 3657   6      6      1.0000
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 3657   6      6      0.9998
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 2286   6      6      0.5404
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 2286   6      6      0.9955
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 2286   6      6      0.9898
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 1679   4      9      0.5384
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 1679   4      4      1.0000
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 1679   4      4      1.0000
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 8935   9      4      0.9407
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 8935   9      9      0.9983
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 8935   9      9      0.9999
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 1424   1      8      0.9707
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 1424   1      1      1.0000
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 1424   1      1      1.0000
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 9674   1      3      0.8391
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 9674   1      1      1.0000
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 9674   1      1      1.0000
#
#
# ______Processing k=7500______
#
#
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 1824   2      3      0.8772
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 1824   2      2      0.9960
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 1824   2      2      1.0000
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 409    1      8      0.4679
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 409    1      1      1.0000
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 409    1      1      1.0000
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 4506   2      8      0.3134
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 4506   2      2      0.9966
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 4506   2      2      0.9530
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 4012   4      9      0.7587
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 4012   4      4      1.0000
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 4012   4      4      0.9637
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 3657   6      4      0.9995
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 3657   6      6      1.0000
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 3657   6      6      1.0000
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 2286   6      4      1.0000
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 2286   6      6      0.8952
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 2286   6      6      0.9979
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 1679   4      9      0.9903
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 1679   4      4      0.9999
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 1679   4      4      0.9987
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 8935   9      4      0.6277
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 8935   9      9      0.9997
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 8935   9      9      0.9991
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 1424   1      8      0.9035
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 1424   1      1      1.0000
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 1424   1      1      0.9999
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 9674   1      2      0.4715
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 9674   1      1      1.0000
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 9674   1      1      1.0000
#
#
# ______Processing k=10000______
#
#
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 1824   2      3      0.8975
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 1824   2      2      0.9999
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 1824   2      2      0.9998
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 409    1      3      0.3227
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 409    1      1      1.0000
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 409    1      1      1.0000
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 4506   2      8      0.9772
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 4506   2      2      0.9984
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 4506   2      2      0.9834
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 4012   4      9      0.6864
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 4012   4      4      1.0000
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 4012   4      4      0.9997
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 3657   6      2      0.6793
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 3657   6      6      1.0000
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 3657   6      6      1.0000
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 2286   6      8      0.2362
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 2286   6      6      0.9882
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 2286   6      6      0.8818
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 1679   4      9      0.9129
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 1679   4      4      1.0000
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 1679   4      4      0.9997
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 8935   9      4      0.9992
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 8935   9      9      0.9974
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 8935   9      9      1.0000
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 1424   1      8      0.8520
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 1424   1      1      1.0000
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 1424   1      1      1.0000
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 9674   1      2      0.6172
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 9674   1      1      0.9996
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 9674   1      1      1.0000
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[30], line 4
#       1 cross_results_l1, knn_distances_l1 = retrain_entropy_for_k_and_indices_v2(trained_mnist, mnist_train_loader, mnist_test_loader, list_of_k, random_indices,metric='l1')
#       3 # Save random_indices to a file
# ----> 4 with open('retrain_data/10000k/l1/10_random_samples_10000k.pkl', 'wb') as f:
#       5     pickle.dump(random_indices, f)
#       7 # Save cross_results to a file
#
# File c:\Users\Lukas\miniconda3\envs\ml_train\Lib\site-packages\IPython\core\interactiveshell.py:324, in _modified_open(file, *args, **kwargs)
#     317 if file in {0, 1, 2}:
#     318     raise ValueError(
#     319         f"IPython won't let you open fd={file} by default "
#     320         "as it is likely to crash IPython. If you know what you are doing, "
#     321         "you can use builtins' open."
#     322     )
# --> 324 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'retrain_data/10000k/l1/10_random_samples_10000k.pkl'

# %%
# Save random_indices to a file
with open('retrain_data/10000k/l1/10_random_samples_10000k.pkl', 'wb') as f:
    pickle.dump(random_indices, f)

# Save cross_results to a file
with open('retrain_data/10000k/l1/cross_results_10000k.pkl', 'wb') as f:
    pickle.dump(cross_results_l1, f)

# Save knn_distances to a file
with open('retrain_data/10000k/l1/knn_distances_10000k.pkl', 'wb') as f:
    pickle.dump(knn_distances_l1, f)  

index_base = random_indices[0]
index_pos = random_indices.index(index_base)
predictions_base_mnist, probabilities_mnist, predicted_classes_mnist, sample_targets_mnist = predict_and_show(trained_mnist, mnist_test_loader, dataset_type='mnist', indices=index_base)
base_error = nn.CrossEntropyLoss()(predictions_base_mnist, sample_targets_mnist)

max_knn = 10000  # Set a maximum K value for visualization

# Limit plotted K values by max_knn (e.g., 10) instead of positional max_points
visualize_results(cross_results_l1, random_indices, selected_index=index_pos, base_mse=base_error, normalize=False, title=f"MNIST Retrain - L1 - Sample {index_base}", ylabel="Loss", max_knn=max_knn)
visualize_results(cross_results_l1, list_of_indices, average=True, normalize=True, title=f"MNIST - Loss L1 Average of {len(random_indices)} Samples", max_knn=max_knn)
# Out:
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 1824   2      2      1.0000

# %%
cross_results_l2, knn_distances_l2 = retrain_entropy_for_k_and_indices_v2(trained_mnist, mnist_train_loader, mnist_test_loader, list_of_k, random_indices,metric='l2')

# Save random_indices to a file
with open('retrain_data/10000k/l2/10_random_samples_10000k.pkl', 'wb') as f:
    pickle.dump(random_indices, f)

# Save cross_results to a file
with open('retrain_data/10000k/l2/cross_results_10000k.pkl', 'wb') as f:
    pickle.dump(cross_results_l2, f)

# Save knn_distances to a file
with open('retrain_data/10000k/l2/knn_distances_10000k.pkl', 'wb') as f:
    pickle.dump(knn_distances_l2, f)

index_base = random_indices[0]
index_pos = random_indices.index(index_base)
predictions_base_mnist, probabilities_mnist, predicted_classes_mnist, sample_targets_mnist = predict_and_show(trained_mnist, mnist_test_loader, dataset_type='mnist', indices=index_base)
base_error = nn.CrossEntropyLoss()(predictions_base_mnist, sample_targets_mnist)

max_knn = 10000  # Set a maximum K value for visualization

# Limit plotted K values by max_knn (e.g., 10) instead of positional max_points
visualize_results(cross_results_l2, random_indices, selected_index=index_pos, base_mse=base_error, normalize=False, title=f"MNIST Retrain - L2 - Sample {index_base}", ylabel="Loss", max_knn=max_knn)
visualize_results(cross_results_l2, list_of_indices, average=True, normalize=True, title=f"MNIST - Loss L2 Average of {len(random_indices)} Samples", max_knn=max_knn)
# Out:
# ______Processing k=1______
#
#
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 1824   2      2      0.9951
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 1824   2      2      1.0000
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 1824   2      2      0.9983
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 409    1      1      0.9995
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 409    1      1      0.9999
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 409    1      1      0.9997
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 4506   2      2      0.9839
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 4506   2      2      0.9758
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 4506   2      2      0.5772
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 4012   4      4      1.0000
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 4012   4      4      1.0000
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 4012   4      4      0.9989
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 3657   6      6      0.9999
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 3657   6      6      0.9914
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 3657   6      6      0.9961
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 2286   6      6      0.6688
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 2286   6      6      0.4977
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 2286   6      6      0.9797
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 1679   4      4      1.0000
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 1679   4      4      1.0000
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 1679   4      4      1.0000
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 8935   9      9      0.9995
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 8935   9      9      0.9999
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 8935   9      9      1.0000
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 1424   1      1      1.0000
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 1424   1      1      0.9998
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 1424   1      1      1.0000
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 9674   1      1      1.0000
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 9674   1      1      1.0000
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 9674   1      1      1.0000
#
#
# ______Processing k=2500______
#
#
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 1824   2      2      0.9453
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 1824   2      2      1.0000
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 1824   2      2      1.0000
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 409    1      1      0.9999
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 409    1      1      0.9999
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 409    1      1      1.0000
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 4506   2      2      0.9189
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 4506   2      2      0.9993
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 4506   2      2      0.9650
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 4012   4      9      0.5440
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 4012   4      4      1.0000
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 4012   4      4      1.0000
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 3657   6      4      0.9999
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 3657   6      6      1.0000
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 3657   6      6      1.0000
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 2286   6      4      0.7134
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 2286   6      6      0.9771
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 2286   6      4      0.5604
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 1679   4      4      1.0000
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 1679   4      4      1.0000
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 1679   4      4      1.0000
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 8935   9      9      0.9071
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 8935   9      9      0.9999
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 8935   9      9      1.0000
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 1424   1      1      0.9998
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 1424   1      1      0.9999
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 1424   1      1      0.9999
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 9674   1      1      0.8240
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 9674   1      1      1.0000
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 9674   1      1      1.0000
#
#
# ______Processing k=5000______
#
#
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 1824   2      8      0.9292
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 1824   2      2      1.0000
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 1824   2      2      1.0000
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 409    1      3      0.8410
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 409    1      1      1.0000
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 409    1      1      1.0000
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 4506   2      2      0.9511
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 4506   2      2      0.9979
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 4506   2      2      0.9958
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 4012   4      9      0.7885
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 4012   4      4      1.0000
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 4012   4      4      1.0000
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 3657   6      4      0.9164
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 3657   6      6      1.0000
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 3657   6      6      1.0000
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 2286   6      6      0.3168
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 2286   6      6      1.0000
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 2286   6      6      0.9995
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 1679   4      9      0.5186
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 1679   4      4      0.9995
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 1679   4      4      0.9992
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 8935   9      4      0.9188
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 8935   9      9      1.0000
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 8935   9      9      0.9998
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 1424   1      8      0.9657
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 1424   1      1      1.0000
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 1424   1      1      0.9996
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 9674   1      3      0.6934
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 9674   1      1      1.0000
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 9674   1      1      1.0000
#
#
# ______Processing k=7500______
#
#
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 1824   2      8      0.9746
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 1824   2      2      0.9714
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 1824   2      2      0.9959
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 409    1      8      0.6153
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 409    1      1      1.0000
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 409    1      1      1.0000
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 4506   2      2      0.6220
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 4506   2      2      0.8675
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 4506   2      2      0.9607
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 4012   4      7      0.6706
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 4012   4      4      0.9993
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 4012   4      4      0.9999
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 3657   6      4      1.0000
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 3657   6      6      1.0000
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 3657   6      6      1.0000
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 2286   6      6      0.9285
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 2286   6      6      0.9999
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 2286   6      6      0.4439
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 1679   4      9      0.9968
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 1679   4      4      1.0000
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 1679   4      4      1.0000
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 8935   9      4      0.9988
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 8935   9      9      0.9867
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 8935   9      9      0.9937
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 1424   1      3      0.9080
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 1424   1      1      0.9991
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 1424   1      1      1.0000
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 9674   1      3      0.5065
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 9674   1      1      1.0000
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 9674   1      1      1.0000
#
#
# ______Processing k=10000______
#
#
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 1824   2      8      0.8486
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 1824   2      2      0.9997
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 1824   2      2      0.9908
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 409    1      8      0.9405
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 409    1      1      1.0000
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 409    1      1      0.9999
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 4506   2      0      0.9304
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 4506   2      2      0.9316
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 4506   2      0      0.8969
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 4012   4      9      0.6860
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 4012   4      4      0.9996
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 4012   4      4      0.9885
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 3657   6      4      0.9439
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 3657   6      6      1.0000
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 3657   6      6      1.0000
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 2286   6      6      0.9817
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 2286   6      6      0.9941
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 2286   6      6      0.9960
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 1679   4      9      0.2726
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 1679   4      4      1.0000
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 1679   4      4      1.0000
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 8935   9      4      0.9934
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 8935   9      9      0.9998
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 8935   9      9      0.9510
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 1424   1      8      0.2343
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 1424   1      1      1.0000
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 1424   1      1      0.9969
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 9674   1      8      0.8261
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 9674   1      1      1.0000
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 9674   1      1      1.0000
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 1824   2      2      1.0000

# %%
cross_results_cosine, knn_distances_cosine = retrain_entropy_for_k_and_indices_v2(trained_mnist, mnist_train_loader, mnist_test_loader, list_of_k, random_indices,metric='cosine')

# Save random_indices to a file
with open('retrain_data/10000k/cosine/10_random_samples_10000k.pkl', 'wb') as f:
    pickle.dump(random_indices, f)

# Save cross_results to a file
with open('retrain_data/10000k/cosine/cross_results_10000k.pkl', 'wb') as f:
    pickle.dump(cross_results_cosine, f)

# Save knn_distances to a file
with open('retrain_data/10000k/cosine/knn_distances_10000k.pkl', 'wb') as f:
    pickle.dump(knn_distances_cosine, f)

index_base = random_indices[0]
index_pos = random_indices.index(index_base)
predictions_base_mnist, probabilities_mnist, predicted_classes_mnist, sample_targets_mnist = predict_and_show(trained_mnist, mnist_test_loader, dataset_type='mnist', indices=index_base)
base_error = nn.CrossEntropyLoss()(predictions_base_mnist, sample_targets_mnist)

max_knn = 10000  # Set a maximum K value for visualization

# Limit plotted K values by max_knn (e.g., 10) instead of positional max_points
visualize_results(cross_results_cosine, random_indices, selected_index=index_pos, base_mse=base_error, normalize=False, title=f"MNIST Retrain - Cosine - Sample {index_base}", ylabel="Loss", max_knn=max_knn)
visualize_results(cross_results_cosine, list_of_indices, average=True, normalize=True, title=f"MNIST - Loss Cosine Average of {len(random_indices)} Samples", max_knn=max_knn)
# Out:
# ______Processing k=1______
#
#
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 1824   2      2      0.9951
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 1824   2      2      0.9920
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 1824   2      2      0.9776
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 409    1      1      0.9995
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 409    1      1      1.0000
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 409    1      1      0.9995
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 4506   2      2      0.9839
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 4506   2      2      0.9999
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 4506   2      0      0.9815
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 4012   4      4      1.0000
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 4012   4      4      1.0000
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 4012   4      4      1.0000
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 3657   6      6      0.9999
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 3657   6      6      0.9817
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 3657   6      6      0.9997
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 2286   6      6      0.6688
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 2286   6      6      0.7757
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 2286   6      6      0.8038
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 1679   4      4      1.0000
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 1679   4      4      1.0000
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 1679   4      4      1.0000
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 8935   9      9      0.9999
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 8935   9      9      1.0000
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 8935   9      9      0.9992
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 1424   1      1      1.0000
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 1424   1      1      0.9999
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 1424   1      1      1.0000
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 9674   1      1      1.0000
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 9674   1      1      1.0000
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 9674   1      1      1.0000
#
#
# ______Processing k=2500______
#
#
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 1824   2      3      0.9007
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 1824   2      2      0.9991
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 1824   2      2      0.9998
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 409    1      1      0.6470
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 409    1      1      1.0000
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 409    1      1      0.9926
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 4506   2      2      0.5240
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 4506   2      2      0.9861
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 4506   2      2      0.9993
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 4012   4      4      0.9034
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 4012   4      4      0.9757
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 4012   4      4      0.9962
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 3657   6      4      0.8358
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 3657   6      6      1.0000
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 3657   6      6      1.0000
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 2286   6      4      0.3467
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 2286   6      6      0.9988
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 2286   6      6      0.9718
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 1679   4      4      0.9991
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 1679   4      4      1.0000
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 1679   4      4      1.0000
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 8935   9      9      0.9998
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 8935   9      9      1.0000
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 8935   9      9      0.9995
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 1424   1      1      0.9998
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 1424   1      1      1.0000
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 1424   1      1      1.0000
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 9674   1      1      0.7325
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 9674   1      1      1.0000
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 9674   1      1      0.9999
#
#
# ______Processing k=5000______
#
#
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 1824   2      3      0.9838
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 1824   2      2      0.9988
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 1824   2      2      1.0000
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 409    1      8      0.9992
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 409    1      1      1.0000
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 409    1      1      0.9997
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 4506   2      2      0.2709
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 4506   2      2      0.5558
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 4506   2      2      0.6249
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 4012   4      9      0.5741
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 4012   4      4      0.9735
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 4012   4      4      1.0000
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 3657   6      4      0.9998
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 3657   6      6      1.0000
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 3657   6      6      1.0000
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 2286   6      2      0.5418
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 2286   6      6      1.0000
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 2286   6      6      0.9446
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 1679   4      4      0.8074
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 1679   4      4      1.0000
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 1679   4      4      1.0000
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 8935   9      9      0.7159
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 8935   9      9      1.0000
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 8935   9      9      0.9992
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 1424   1      8      0.3835
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 1424   1      1      1.0000
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 1424   1      1      1.0000
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 9674   1      3      0.7291
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 9674   1      1      1.0000
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 9674   1      1      1.0000
#
#
# ______Processing k=7500______
#
#
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 1824   2      8      0.6013
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 1824   2      2      0.9694
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 1824   2      2      0.9413
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 409    1      3      0.9342
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 409    1      1      0.9997
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 409    1      1      1.0000
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 4506   2      8      0.2460
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 4506   2      2      0.9982
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 4506   2      2      0.9970
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 4012   4      9      0.5690
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 4012   4      4      0.9999
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 4012   4      4      0.9991
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 3657   6      4      0.9981
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 3657   6      6      1.0000
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 3657   6      6      1.0000
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 2286   6      7      0.2904
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 2286   6      6      0.9958
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 2286   6      6      0.6304
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 1679   4      9      0.4600
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 1679   4      4      1.0000
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 1679   4      4      1.0000
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 8935   9      4      0.9802
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 8935   9      9      1.0000
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 8935   9      9      1.0000
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 1424   1      3      0.9763
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 1424   1      1      0.9999
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 1424   1      1      1.0000
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 9674   1      8      0.6533
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 9674   1      1      1.0000
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 9674   1      1      1.0000
#
#
# ______Processing k=10000______
#
#
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 1824   2      3      0.8485
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 1824   2      2      0.9999
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 1824   2      2      0.9999
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 409    1      3      0.8689
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 409    1      1      1.0000
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 409    1      1      0.9976
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 4506   2      0      0.8407
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 4506   2      2      0.9927
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 4506   2      2      0.9385
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 4012   4      9      0.9856
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 4012   4      4      0.9990
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 4012   4      4      0.9958
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 3657   6      4      0.9998
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 3657   6      6      1.0000
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 3657   6      6      1.0000
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 2286   6      7      0.8004
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 2286   6      6      0.9983
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 2286   6      6      0.9362
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 1679   4      3      0.4527
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 1679   4      4      1.0000
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 1679   4      4      1.0000
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 8935   9      4      0.9999
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 8935   9      9      1.0000
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 8935   9      9      0.9971
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 1424   1      5      0.2792
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 1424   1      1      1.0000
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 1424   1      1      1.0000
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 9674   1      3      0.9961
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
# 9674   1      1      1.0000
# All seeds set to: 42
# Model weights initialized with seed: 42
# MNIST Predictions:
# --------------------------------------------------
# Index  True   Pred   Confidence
# --------------------------------------------------
#
0.07666587829589844, 0.07670742273330688, 0.07685089111328125, 0.07704651355743408, 0.0771254301071167, 0.07718640565872192, 0.07766765356063843, 0.07768148183822632, 0.07817065715789795, 0.07825565338134766, 0.07848477363586426, 0.07850849628448486, 0.07917249202728271, 0.07932007312774658, 0.07934892177581787, 0.07948946952819824, 0.07985234260559082, 0.08077448606491089, 0.08083099126815796, 0.08132636547088623, 0.08151125907897949, 0.08177751302719116, 0.08183532953262329, 0.08231937885284424, 0.0828317403793335, 0.08326452970504761, 0.0833922028541565, 0.0834423303604126, 0.08351141214370728, 0.08376121520996094, 0.08487385511398315, 0.08501231670379639, 0.08518600463867188, 0.08545833826065063, 0.08554649353027344, 0.08559536933898926, 0.0858151912689209, 0.08592426776885986, 0.08652383089065552, 0.08676689863204956, 0.08689820766448975, 0.08695042133331299, 0.08714020252227783, 0.08717381954193115, 0.08727771043777466, 0.08751493692398071, 0.08774691820144653, 0.08787155151367188, 0.08827048540115356]]), (100, [[0.07854366302490234, 0.07910805940628052, 0.07920050621032715, 0.07924461364746094, 0.07968425750732422, 0.08005285263061523, 0.0801500678062439, 0.08060884475708008, 0.08087480068206787, 0.08096611499786377, 0.08102917671203613, 0.08112543821334839, 0.08117526769638062, 0.08130282163619995, 0.08137792348861694, 0.08151161670684814, 0.08153975009918213, 0.08156585693359375, 0.08242219686508179, 0.08242696523666382, 0.08261239528656006, 0.0827341079711914, 0.08291923999786377, 0.08294588327407837, 0.08301305770874023, 0.08309882879257202, 0.08347177505493164, 0.08358573913574219, 0.08361643552780151, 0.08379662036895752, 0.08430981636047363, 0.08486783504486084, 0.08495092391967773, 0.08553272485733032, 0.0865362286567688, 0.0867797136 ...

# %%
import statistics as stats

closest = knn_distances_cosine['closest_distances']  # your dict

def flatten_one_level(x):
    if not x:
        return []
    if isinstance(x[0], (list, tuple)):
        out = []
        for sub in x:
            if isinstance(sub, (list, tuple)):
                out.extend(sub)
            else:
                out.append(sub)
        return out
    return x

summary = {}
for k, v in closest.items():
    vals = flatten_one_level(v)
    if vals:  # skip empty
        summary[k] = {
            "min": min(vals),
            "max": max(vals),
            "avg": stats.fmean(vals),  # numerically robust mean
        }

# Example: print nicely, sorted by key
for k in sorted(summary):
    s = summary[k]
    print(f"{k}: min={s['min']:.6g}  max={s['max']:.6g}  avg={s['avg']:.6g}")
    
# Sort by keys
x = sorted(summary.keys())
y_min = [summary[k]["min"] for k in x]
y_max = [summary[k]["max"] for k in x]
y_avg = [summary[k]["avg"] for k in x]

plt.figure(figsize=(8,5))

# Plot avg as solid line
plt.plot(x, y_avg, label="Average", color="blue", linewidth=2)

# Plot min and max as dotted lines
plt.plot(x, y_min, label="Min", color="red", linestyle="dotted")
plt.plot(x, y_max, label="Max", color="green", linestyle="dotted")

plt.title("KNN Distances Summary")
plt.xlabel("K")
plt.ylabel("Distance")
plt.legend()
plt.grid(True)
plt.show()
# Out:
# 1: min=0.0205784  max=0.0460466  avg=0.0333025
# 50: min=0.0462037  max=0.0882705  avg=0.0688039
# 100: min=0.056414  max=0.10535  avg=0.0833447
